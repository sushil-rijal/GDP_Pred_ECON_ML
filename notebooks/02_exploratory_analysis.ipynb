# %% [markdown]
# # 02 â€” Exploratory analysis
#
# Describe the estimation sample before selecting models.

# %%
import pandas as pd
from src.descriptive import distribution_moments, correlation_matrix
panel = pd.read_csv('data/processed/analysis_panel.csv')
distribution_moments(panel)
