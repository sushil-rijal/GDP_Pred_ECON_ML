# %% [markdown]
# # 04 â€” Dynamic panel GMM
#
# Implement only after selecting endogenous variables and a limited instrument strategy. Report AR(1), AR(2), Hansen/Sargan diagnostics, and instrument count.
