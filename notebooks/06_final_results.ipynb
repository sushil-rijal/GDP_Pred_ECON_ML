# %% [markdown]
# # Global Economic Growth Analysis â€” Final results
#
# Reader-facing entry point after the pipeline and model notebooks are complete.

# %%
import pandas as pd
from src.descriptive import distribution_moments
panel = pd.read_csv('data/processed/analysis_panel.csv')
print(f'Countries: {panel.country_code.nunique():,}')
print(f'Years: {panel.year.min()}â€“{panel.year.max()}')
distribution_moments(panel)
